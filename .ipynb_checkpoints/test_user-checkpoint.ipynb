# %%
import pandas as pd

# %%
train_users_pd = pd.read_csv('./train_users.csv')

# %%
train_users_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 213466 entries, 0 to 213465
# Data columns (total 16 columns):
# id                         213466 non-null object
# date_account_created       213466 non-null object
# timestamp_first_active     213466 non-null int64
# date_first_booking         88908 non-null object
# gender                     213466 non-null object
# age                        125474 non-null float64
# signup_method              213466 non-null object
# signup_flow                213466 non-null int64
# language                   213466 non-null object
# affiliate_channel          213466 non-null object
# affiliate_provider         213466 non-null object
# first_affiliate_tracked    207401 non-null object
# signup_app                 213466 non-null object
# first_device_type          213466 non-null object
# first_browser              213466 non-null object
# country_destination        213466 non-null object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 27.7+ MB

# %%
train_users_pd.describe()
# Out:
#        timestamp_first_active            age    signup_flow
# count            2.134660e+05  125474.000000  213466.000000
# mean             2.013085e+13      49.667007       3.267232
# std              9.253776e+09     155.658666       7.637495
# min              2.009032e+13       1.000000       0.000000
# 25%              2.012123e+13      28.000000       0.000000
# 50%              2.013091e+13      34.000000       0.000000
# 75%              2.014031e+13      43.000000       0.000000
# max              2.014063e+13    2014.000000      25.000000

# %%
train_users_pd[:3]
# Out:
#            id date_account_created  timestamp_first_active date_first_booking  \
# 0  gxn3p5htnn           2010-06-28          20090319043255                NaN
# 1  820tgsjxq7           2011-05-25          20090523174809                NaN
# 2  4ft3gnwmtx           2010-09-28          20090609231247         2010-08-02
#
#       gender  age signup_method  signup_flow language affiliate_channel  \
# 0  -unknown-  NaN      facebook            0       en            direct
# 1       MALE   38      facebook            0       en               seo
# 2     FEMALE   56         basic            3       en            direct
#
#   affiliate_provider first_affiliate_tracked signup_app first_device_type  \
# 0             direct               untracked        Web       Mac Desktop
# 1             google               untracked        Web       Mac Desktop
# 2             direct               untracked        Web   Windows Desktop
#
#   first_browser country_destination
# 0        Chrome                 NDF
# 1        Chrome                 NDF
# 2            IE                  US

# %% [markdown]
# age, gender, language 만 테스트로 돌려볼 예정

# %%
train_users_pd['gender'].unique()
# Out:
# array(['-unknown-', 'MALE', 'FEMALE', 'OTHER'], dtype=object)

# %%
train_users_pd['age'].unique()
# Out:
# array([             nan,   3.80000000e+01,   5.60000000e+01,
#          4.20000000e+01,   4.10000000e+01,   4.60000000e+01,
#          4.70000000e+01,   5.00000000e+01,   3.60000000e+01,
#          3.70000000e+01,   3.30000000e+01,   3.10000000e+01,
#          2.90000000e+01,   3.00000000e+01,   4.00000000e+01,
#          2.60000000e+01,   3.20000000e+01,   3.50000000e+01,
#          5.90000000e+01,   4.90000000e+01,   4.40000000e+01,
#          3.40000000e+01,   2.80000000e+01,   1.90000000e+01,
#          5.30000000e+01,   5.20000000e+01,   3.90000000e+01,
#          5.70000000e+01,   2.50000000e+01,   5.40000000e+01,
#          6.90000000e+01,   6.30000000e+01,   4.30000000e+01,
#          5.50000000e+01,   6.50000000e+01,   5.80000000e+01,
#          6.10000000e+01,   1.80000000e+01,   5.00000000e+00,
#          2.70000000e+01,   4.50000000e+01,   6.00000000e+01,
#          4.80000000e+01,   5.10000000e+01,   6.40000000e+01,
#          7.20000000e+01,   7.00000000e+01,   6.70000000e+01,
#          7.30000000e+01,   2.01400000e+03,   1.04000000e+02,
#          6.60000000e+01,   1.05000000e+02,   6.80000000e+01,
#          9.50000000e+01,   2.40000000e+01,   9.40000000e+01,
#          7.50000000e+01,   7.90000000e+01,   6.20000000e+01,
#          2.01300000e+03,   1.60000000e+01,   4.00000000e+00,
#          2.30000000e+01,   1.01000000e+02,   9.80000000e+01,
#          7.60000000e+01,   7.40000000e+01,   8.70000000e+01,
#          9.20000000e+01,   1.15000000e+02,   7.10000000e+01,
#          8.40000000e+01,   1.07000000e+02,   7.80000000e+01,
#          9.90000000e+01,   1.10000000e+02,   1.02000000e+02,
#          8.20000000e+01,   7.70000000e+01,   2.20000000e+01,
#          8.90000000e+01,   2.10000000e+01,   1.50000000e+01,
#          2.00000000e+01,   1.03000000e+02,   2.00000000e+00,
#          1.70000000e+01,   8.60000000e+01,   9.70000000e+01,
#          8.10000000e+01,   9.00000000e+01,   8.80000000e+01,
#          8.00000000e+01,   1.00000000e+02,   9.10000000e+01,
#          1.06000000e+02,   8.30000000e+01,   8.50000000e+01,
#          1.08000000e+02,   1.13000000e+02,   1.09000000e+02,
#          9.30000000e+01,   9.60000000e+01,   1.94900000e+03,
#          1.11000000e+02,   1.93100000e+03,   1.93200000e+03,
#          1.12000000e+02,   1.92800000e+03,   1.00000000e+00,
#          1.93600000e+03,   1.93300000e+03,   1.93500000e+03,
#          1.92500000e+03,   1.95200000e+03,   1.50000000e+02,
#          1.92700000e+03,   1.32000000e+02,   1.95300000e+03,
#          1.94200000e+03,   1.99500000e+03,   2.00800000e+03,
#          1.92400000e+03,   1.92900000e+03,   1.94700000e+03,
#          1.93800000e+03,   1.92600000e+03])

# %%
train_users_pd['language'].unique()
# Out:
# array(['en', 'fr', 'de', 'es', 'it', 'pt', 'zh', 'ko', 'ja', 'ru', 'pl',
#        'el', 'sv', 'nl', 'hu', 'da', 'id', 'fi', 'no', 'tr', 'th', 'cs',
#        'hr', 'ca', 'is'], dtype=object)

# %% [markdown]
# train_users_pd['gender'].unique()
# array(['-unknown-', 'MALE', 'FEMALE', 'OTHER'], dtype=object)
# OTHER 와 -unknown- 다를까? 세상의 모든 존재는 MALE 아니면 FEMALE 이다. OTHER == -unknown- 은 UNKOWN 으로 바꾸는게 좋을듯

# %%
train_users_pd.loc[train_users_pd['gender'] == '-unknown-','gender'] = 'UNKNOWN'
train_users_pd.loc[train_users_pd['gender'] == 'OTHER','gender'] = 'UNKNOWN'

# %%
train_users_pd['gender'].unique()
# Out:
# array(['UNKNOWN', 'MALE', 'FEMALE'], dtype=object)

# %% [markdown]
# age 의 경우 이상값이 들어 있음으로 max = 2014.0 , min = 1.0
# 10 보다 작거나 100 보다 큰 사람들은 그 사람들이 그렇다기 보다는 자기 나이를 숨기고 싶거나 그런식의 느낌이 아닐까?

# %%
print(train_users_pd['age'].max())
print(train_users_pd['age'].min())
# Out:
# 2014.0
# 1.0

# %%
train_users_pd.loc[train_users_pd['age'] > 80]
# Out:
#                 id date_account_created  timestamp_first_active  \
# 388     v2x0ms9c62           2010-04-11          20100411065602
# 398     9ouah6tc30           2010-04-12          20100412231534
# 627     dc3udjfdij           2010-05-19          20100519012455
# 645     ixv5186g1h           2010-05-21          20100521070029
# 673     umf1wdk9uc           2010-05-25          20100525155541
# 777     kqf8b3ta98           2010-06-07          20100607184626
# 1040    m82epwn7i8           2010-07-14          20100714230556
# 1177    2th813zdx7           2010-07-25          20100725234419
# 1190    qc9se9qucz           2010-07-27          20100727002029
# 1200    3amf04n3o3           2010-07-27          20100727190447
# 1208    cguxptdi6h           2010-07-28          20100728034415
# 1239    6vpmryt377           2010-07-30          20100730055204
# 1257    uxy91xb5p2           2010-08-01          20100801071023
# 1308    bno0vva4uz           2010-08-06          20100806133725
# 1314    4wir86n2az           2010-08-06          20100806201512
# 1474    h3rrmak4tu           2010-08-21          20100821225214
# 1502    fou0j7fhnm           2010-08-24          20100824205045
# 1529    1j5uk4f0ay           2010-08-27          20100827135415
# 1615    uqncyj8byz           2010-09-04          20100904210638
# 1619    9lkved7fhg           2010-09-05          20100905050114
# 1739    eef74e94rg           2010-09-15          20100915023255
# 1826    kfeh5350pi           2010-09-21          20100921134556
# 1860    9aouhu15rk           2010-09-23          20100923114758
# 1879    8wxkkbpwuk           2010-09-25          20100925234241
# 1889    g4pymtxkrk           2010-09-26          20100926234020
# 2228    i0j7vqzk2m           2010-10-29          20101029182448
# 2235    9s9mdj9xeb           2010-10-30          20101030104540
# 2289    v1xp5ggiti           2010-11-04          20101104235028
# 2497    cmaysyaya1           2010-11-28          20101128214740
# 2582    aq0lqrjf2y           2010-12-06          20101206173457
# ...            ...                  ...                     ...
# 209228  v4o93j53zn           2014-06-23          20140623174300
# 209672  1zzmeakk1b           2014-06-24          20140624051116
# 210086  0fjffldr3f           2014-06-24          20140624224114
# 210232  nhzq5d8nby           2014-06-25          20140625030229
# 210257  smzfy2c47g           2014-06-25          20140625035237
# 210335  oldf6jxjv1           2014-06-25          20140625054539
# 210350  x1kd3fm9f5           2014-06-25          20140625060832
# 210793  ty6g90h81q           2014-06-26          20140626003400
# 210928  xr911lto8m           2014-06-26          20140626041212
# 211074  9ppttyasd8           2014-06-26          20140626131631
# 211196  xcm902wnfb           2014-06-26          20140626191640
# 211228  n9ks4ugwqg           2014-06-26          20140626202148
# 211373  dtwwccb707           2014-06-27          20140627002940
# 211388  r5m2au58pp           2014-06-27          20140627004836
# 211424  mi1cn9suyv           2014-06-27          20140627022018
# 211496  025sv1949e           2014-06-27          20140627043908
# 211552  mi21cgnfr3           2014-06-27          20140627064132
# 211728  ldwhkrhtk6           2014-06-27          20140627184539
# 212292  u13vudpnue           2014-06-28          20140628211126
# 212372  j7xbbox53t           2014-06-28          20140628234821
# 212419  p6efkjvhld           2014-06-29          20140629015756
# 212720  a6r17kfpyi           2014-06-29          20140629193647
# 212786  4wub3u531r           2014-06-29          20140629214926
# 212862  ab3s6b58w5           2014-06-30          20140630001257
# 212981  l6y2gwgoni           2014-06-30          20140630035617
# 213106  1c83n850up           2014-06-30          20140630085741
# 213182  kh8odg7wnv           2014-06-30          20140630164858
# 213199  lyuno62d1q           2014-06-30          20140630171821
# 213217  pw9nfo1ulb           2014-06-30          20140630174359
# 213345  gfend4omwv           2014-06-30          20140630205707
#
#        date_first_booking   gender   age signup_method  signup_flow language  \
# 388            2010-04-13  UNKNOWN  2014         basic            3       en
# 398            2010-04-12   FEMALE   104      facebook            3       en
# 627            2010-06-16  UNKNOWN   105         basic            2       en
# 645                   NaN     MALE    95         basic            0       en
# 673                   NaN   FEMALE  2014         basic            2       en
# 777                   NaN   FEMALE    94         basic            0       en
# 1040           2010-07-15     MALE  2014      facebook            0       en
# 1177           2010-07-26     MALE  2013      facebook            3       en
# 1190           2010-07-27  UNKNOWN   105         basic            2       en
# 1200           2010-07-29   FEMALE  2014         basic            2       en
# 1208           2010-07-28  UNKNOWN   105         basic            3       en
# 1239           2010-07-30   FEMALE  2014         basic            0       en
# 1257           2010-08-01     MALE  2014      facebook            3       en
# 1308                  NaN     MALE  2014         basic            3       en
# 1314                  NaN     MALE   104         basic            2       en
# 1474                  NaN     MALE  2014      facebook            2       pt
# 1502           2010-08-25   FEMALE  2014         basic            3       en
# 1529                  NaN     MALE   105      facebook            2       en
# 1615           2010-10-03   FEMALE   101         basic            2       en
# 1619           2010-09-05   FEMALE    98         basic            3       en
# 1739           2010-09-20  UNKNOWN   105      facebook            2       en
# 1826           2010-09-26  UNKNOWN  2014      facebook            2       en
# 1860           2011-03-25   FEMALE  2014         basic            2       en
# 1879           2010-10-02   FEMALE    87      facebook            2       en
# 1889           2010-09-27   FEMALE    92         basic            0       en
# 2228                  NaN     MALE   115      facebook            0       en
# 2235                  NaN     MALE   104      facebook            2       en
# 2289           2011-05-16  UNKNOWN   105         basic            2       en
# 2497           2010-12-14     MALE    84         basic            2       en
# 2582           2010-12-06  UNKNOWN  2014      facebook            3       en
# ...                   ...      ...   ...           ...          ...      ...
# 209228                NaN     MALE   110      facebook            0       en
# 209672                NaN     MALE   105      facebook            0       en
# 210086         2014-06-24  UNKNOWN   105         basic            0       en
# 210232         2014-06-25   FEMALE   105         basic            0       en
# 210257         2014-07-21  UNKNOWN   105         basic            0       en
# 210335         2014-12-23  UNKNOWN   105         basic           25       en
# 210350                NaN   FEMALE    91      facebook           25       es
# 210793                NaN   FEMALE   105         basic            0       en
# 210928         2014-07-02     MALE   105         basic            0       en
# 211074                NaN   FEMALE   110      facebook            0       fr
# 211196         2015-02-08  UNKNOWN   105         basic            0       en
# 211228         2014-07-01     MALE   110         basic           25       en
# 211373                NaN   FEMALE   105         basic            0       en
# 211388         2014-07-24  UNKNOWN   105         basic            0       en
# 211424         2014-06-27  UNKNOWN   105         basic            0       en
# 211496         2014-07-11   FEMALE  1926         basic            0       en
# 211552                NaN   FEMALE   101         basic            0       en
# 211728         2014-06-27     MALE   105         basic            0       en
# 212292                NaN  UNKNOWN    88      facebook            0       en
# 212372                NaN     MALE    82         basic            0       en
# 212419         2014-11-10   FEMALE    89         basic            0       en
# 212720         2014-06-29  UNKNOWN   105         basic            0       en
# 212786                NaN     MALE   110      facebook            0       en
# 212862                NaN   FEMALE    81         basic            0       en
# 212981         2014-07-27  UNKNOWN   105         basic            0       en
# 213106                NaN     MALE   110      facebook           25       en
# 213182         2014-07-04   FEMALE   105         basic            0       en
# 213199         2014-07-07     MALE   105         basic            0       en
# 213217                NaN   FEMALE    95      facebook            0       fr
# 213345         2014-07-01   FEMALE   105         basic            0       en
#
#        affiliate_channel affiliate_provider first_affiliate_tracked  \
# 388                other         craigslist               untracked
# 398                other         craigslist                  linked
# 627                other         craigslist                     omg
# 645               direct             direct               untracked
# 673                other         craigslist               untracked
# 777              content             google                  linked
# 1040               other         craigslist               untracked
# 1177              direct             direct               untracked
# 1190               other         craigslist               untracked
# 1200              direct             direct               untracked
# 1208              direct             direct               untracked
# 1239              direct             direct               untracked
# 1257              direct             direct               untracked
# 1308               other         craigslist                  linked
# 1314              direct             direct               untracked
# 1474               other         craigslist               untracked
# 1502       sem-non-brand             google               untracked
# 1529               other         craigslist                  linked
# 1615              direct             direct               untracked
# 1619                 seo             google               untracked
# 1739       sem-non-brand             google           tracked-other
# 1826              direct             direct               untracked
# 1860                 seo             google                  linked
# 1879              direct             direct               untracked
# 1889       sem-non-brand             google               untracked
# 2228               other         craigslist                     NaN
# 2235             content             google                     omg
# 2289              direct             direct               untracked
# 2497              direct             direct               untracked
# 2582       sem-non-brand             google                  linked
# ...                  ...                ...                     ...
# 209228            direct             direct                  linked
# 209672            direct             direct                  linked
# 210086            direct             direct               untracked
# 210232         sem-brand             google                     omg
# 210257            direct             direct               untracked
# 210335            direct             direct               untracked
# 210350            direct             direct               untracked
# 210793     sem-non-brand             google                     omg
# 210928            direct             direct                  linked
# 211074     sem-non-brand             google                     omg
# 211196            direct             direct                  linked
# 211228            direct             direct               untracked
# 211373            direct             direct               untracked
# 211388         sem-brand             google                     omg
# 211424            direct             direct                  linked
# 211496            direct             direct               untracked
# 211552         sem-brand             google                     omg
# 211728            direct             direct                  linked
# 212292            direct             direct                  linked
# 212372            direct             direct               untracked
# 212419         sem-brand             google                     omg
# 212720            direct             direct                     omg
# 212786            direct             direct               untracked
# 212862         sem-brand             google               untracked
# 212981         sem-brand             google                     omg
# 213106            direct             direct               untracked
# 213182            direct             direct                  linked
# 213199            direct             direct               untracked
# 213217               seo           facebook                  linked
# 213345            direct             direct                     omg
#
#        signup_app first_device_type   first_browser country_destination
# 388           Web   Windows Desktop         Firefox                  FR
# 398           Web            iPhone   Mobile Safari                  FR
# 627           Web       Mac Desktop          Safari                  FR
# 645           Web       Mac Desktop         Firefox                 NDF
# 673           Web       Mac Desktop          Safari                 NDF
# 777           Web       Mac Desktop          Safari                 NDF
# 1040          Web       Mac Desktop          Chrome                  US
# 1177          Web       Mac Desktop          Chrome                  US
# 1190          Web       Mac Desktop         Firefox                  US
# 1200          Web   Windows Desktop              IE                  US
# 1208          Web       Mac Desktop         Firefox                  US
# 1239          Web       Mac Desktop         Firefox                  CA
# 1257          Web   Windows Desktop          Chrome                  US
# 1308          Web   Windows Desktop          Chrome                 NDF
# 1314          Web     Other/Unknown       -unknown-                 NDF
# 1474          Web       Mac Desktop          Safari                 NDF
# 1502          Web   Windows Desktop          Chrome                  US
# 1529          Web   Windows Desktop              IE                 NDF
# 1615          Web   Windows Desktop              IE                  US
# 1619          Web       Mac Desktop          Safari                  US
# 1739          Web     Other/Unknown  Mobile Firefox                  US
# 1826          Web       Mac Desktop         Firefox               other
# 1860          Web   Windows Desktop              IE                  US
# 1879          Web   Windows Desktop         Firefox                  US
# 1889          Web              iPad   Mobile Safari                  US
# 2228          Web     Other/Unknown       -unknown-                 NDF
# 2235          Web       Mac Desktop          Safari                 NDF
# 2289          Web   Windows Desktop          Chrome                  US
# 2497          Web       Mac Desktop          Chrome               other
# 2582          Web              iPad   Mobile Safari                  FR
# ...           ...               ...             ...                 ...
# 209228        Web       Mac Desktop          Chrome                 NDF
# 209672      Moweb            iPhone   Mobile Safari                 NDF
# 210086        Web   Windows Desktop         Firefox                  US
# 210232        Web       Mac Desktop          Safari                  FR
# 210257        Web       Mac Desktop          Safari                  US
# 210335        iOS            iPhone       -unknown-                  US
# 210350        iOS            iPhone       -unknown-                 NDF
# 210793        Web   Windows Desktop              IE                 NDF
# 210928        Web       Mac Desktop          Safari                  GB
# 211074        Web   Windows Desktop              IE                 NDF
# 211196      Moweb            iPhone   Mobile Safari                  US
# 211228        iOS            iPhone       -unknown-                  US
# 211373        Web       Mac Desktop          Safari                 NDF
# 211388        Web       Mac Desktop         Firefox                  US
# 211424        Web              iPad   Mobile Safari                  US
# 211496        Web   Windows Desktop         Firefox                  US
# 211552        Web   Windows Desktop          Chrome                 NDF
# 211728        Web       Mac Desktop          Chrome                  US
# 212292      Moweb     Android Phone   Chrome Mobile                 NDF
# 212372        Web   Windows Desktop              IE                 NDF
# 212419        Web   Windows Desktop         Firefox                  US
# 212720        Web       Mac Desktop          Safari                  US
# 212786        Web   Windows Desktop              IE                 NDF
# 212862        Web              iPad   Mobile Safari                 NDF
# 212981        Web       Mac Desktop          Chrome                  US
# 213106        iOS            iPhone       -unknown-                 NDF
# 213182        Web            iPhone   Mobile Safari                  ES
# 213199        Web   Windows Desktop          Chrome                  US
# 213217      Moweb            iPhone   Mobile Safari                 NDF
# 213345        Web            iPhone   Mobile Safari                  US
#
# [2771 rows x 16 columns]

# %%
train_users_pd.loc[train_users_pd['age'] > 80]
# Out:
#                 id date_account_created  timestamp_first_active  \
# 388     v2x0ms9c62           2010-04-11          20100411065602
# 398     9ouah6tc30           2010-04-12          20100412231534
# 627     dc3udjfdij           2010-05-19          20100519012455
# 645     ixv5186g1h           2010-05-21          20100521070029
# 673     umf1wdk9uc           2010-05-25          20100525155541
# 777     kqf8b3ta98           2010-06-07          20100607184626
# 1040    m82epwn7i8           2010-07-14          20100714230556
# 1177    2th813zdx7           2010-07-25          20100725234419
# 1190    qc9se9qucz           2010-07-27          20100727002029
# 1200    3amf04n3o3           2010-07-27          20100727190447
# 1208    cguxptdi6h           2010-07-28          20100728034415
# 1239    6vpmryt377           2010-07-30          20100730055204
# 1257    uxy91xb5p2           2010-08-01          20100801071023
# 1308    bno0vva4uz           2010-08-06          20100806133725
# 1314    4wir86n2az           2010-08-06          20100806201512
# 1474    h3rrmak4tu           2010-08-21          20100821225214
# 1502    fou0j7fhnm           2010-08-24          20100824205045
# 1529    1j5uk4f0ay           2010-08-27          20100827135415
# 1615    uqncyj8byz           2010-09-04          20100904210638
# 1619    9lkved7fhg           2010-09-05          20100905050114
# 1739    eef74e94rg           2010-09-15          20100915023255
# 1826    kfeh5350pi           2010-09-21          20100921134556
# 1860    9aouhu15rk           2010-09-23          20100923114758
# 1879    8wxkkbpwuk           2010-09-25          20100925234241
# 1889    g4pymtxkrk           2010-09-26          20100926234020
# 2228    i0j7vqzk2m           2010-10-29          20101029182448
# 2235    9s9mdj9xeb           2010-10-30          20101030104540
# 2289    v1xp5ggiti           2010-11-04          20101104235028
# 2497    cmaysyaya1           2010-11-28          20101128214740
# 2582    aq0lqrjf2y           2010-12-06          20101206173457
# ...            ...                  ...                     ...
# 209228  v4o93j53zn           2014-06-23          20140623174300
# 209672  1zzmeakk1b           2014-06-24          20140624051116
# 210086  0fjffldr3f           2014-06-24          20140624224114
# 210232  nhzq5d8nby           2014-06-25          20140625030229
# 210257  smzfy2c47g           2014-06-25          20140625035237
# 210335  oldf6jxjv1           2014-06-25          20140625054539
# 210350  x1kd3fm9f5           2014-06-25          20140625060832
# 210793  ty6g90h81q           2014-06-26          20140626003400
# 210928  xr911lto8m           2014-06-26          20140626041212
# 211074  9ppttyasd8           2014-06-26          20140626131631
# 211196  xcm902wnfb           2014-06-26          20140626191640
# 211228  n9ks4ugwqg           2014-06-26          20140626202148
# 211373  dtwwccb707           2014-06-27          20140627002940
# 211388  r5m2au58pp           2014-06-27          20140627004836
# 211424  mi1cn9suyv           2014-06-27          20140627022018
# 211496  025sv1949e           2014-06-27          20140627043908
# 211552  mi21cgnfr3           2014-06-27          20140627064132
# 211728  ldwhkrhtk6           2014-06-27          20140627184539
# 212292  u13vudpnue           2014-06-28          20140628211126
# 212372  j7xbbox53t           2014-06-28          20140628234821
# 212419  p6efkjvhld           2014-06-29          20140629015756
# 212720  a6r17kfpyi           2014-06-29          20140629193647
# 212786  4wub3u531r           2014-06-29          20140629214926
# 212862  ab3s6b58w5           2014-06-30          20140630001257
# 212981  l6y2gwgoni           2014-06-30          20140630035617
# 213106  1c83n850up           2014-06-30          20140630085741
# 213182  kh8odg7wnv           2014-06-30          20140630164858
# 213199  lyuno62d1q           2014-06-30          20140630171821
# 213217  pw9nfo1ulb           2014-06-30          20140630174359
# 213345  gfend4omwv           2014-06-30          20140630205707
#
#        date_first_booking   gender   age signup_method  signup_flow language  \
# 388            2010-04-13  UNKNOWN  2014         basic            3       en
# 398            2010-04-12   FEMALE   104      facebook            3       en
# 627            2010-06-16  UNKNOWN   105         basic            2       en
# 645                   NaN     MALE    95         basic            0       en
# 673                   NaN   FEMALE  2014         basic            2       en
# 777                   NaN   FEMALE    94         basic            0       en
# 1040           2010-07-15     MALE  2014      facebook            0       en
# 1177           2010-07-26     MALE  2013      facebook            3       en
# 1190           2010-07-27  UNKNOWN   105         basic            2       en
# 1200           2010-07-29   FEMALE  2014         basic            2       en
# 1208           2010-07-28  UNKNOWN   105         basic            3       en
# 1239           2010-07-30   FEMALE  2014         basic            0       en
# 1257           2010-08-01     MALE  2014      facebook            3       en
# 1308                  NaN     MALE  2014         basic            3       en
# 1314                  NaN     MALE   104         basic            2       en
# 1474                  NaN     MALE  2014      facebook            2       pt
# 1502           2010-08-25   FEMALE  2014         basic            3       en
# 1529                  NaN     MALE   105      facebook            2       en
# 1615           2010-10-03   FEMALE   101         basic            2       en
# 1619           2010-09-05   FEMALE    98         basic            3       en
# 1739           2010-09-20  UNKNOWN   105      facebook            2       en
# 1826           2010-09-26  UNKNOWN  2014      facebook            2       en
# 1860           2011-03-25   FEMALE  2014         basic            2       en
# 1879           2010-10-02   FEMALE    87      facebook            2       en
# 1889           2010-09-27   FEMALE    92         basic            0       en
# 2228                  NaN     MALE   115      facebook            0       en
# 2235                  NaN     MALE   104      facebook            2       en
# 2289           2011-05-16  UNKNOWN   105         basic            2       en
# 2497           2010-12-14     MALE    84         basic            2       en
# 2582           2010-12-06  UNKNOWN  2014      facebook            3       en
# ...                   ...      ...   ...           ...          ...      ...
# 209228                NaN     MALE   110      facebook            0       en
# 209672                NaN     MALE   105      facebook            0       en
# 210086         2014-06-24  UNKNOWN   105         basic            0       en
# 210232         2014-06-25   FEMALE   105         basic            0       en
# 210257         2014-07-21  UNKNOWN   105         basic            0       en
# 210335         2014-12-23  UNKNOWN   105         basic           25       en
# 210350                NaN   FEMALE    91      facebook           25       es
# 210793                NaN   FEMALE   105         basic            0       en
# 210928         2014-07-02     MALE   105         basic            0       en
# 211074                NaN   FEMALE   110      facebook            0       fr
# 211196         2015-02-08  UNKNOWN   105         basic            0       en
# 211228         2014-07-01     MALE   110         basic           25       en
# 211373                NaN   FEMALE   105         basic            0       en
# 211388         2014-07-24  UNKNOWN   105         basic            0       en
# 211424         2014-06-27  UNKNOWN   105         basic            0       en
# 211496         2014-07-11   FEMALE  1926         basic            0       en
# 211552                NaN   FEMALE   101         basic            0       en
# 211728         2014-06-27     MALE   105         basic            0       en
# 212292                NaN  UNKNOWN    88      facebook            0       en
# 212372                NaN     MALE    82         basic            0       en
# 212419         2014-11-10   FEMALE    89         basic            0       en
# 212720         2014-06-29  UNKNOWN   105         basic            0       en
# 212786                NaN     MALE   110      facebook            0       en
# 212862                NaN   FEMALE    81         basic            0       en
# 212981         2014-07-27  UNKNOWN   105         basic            0       en
# 213106                NaN     MALE   110      facebook           25       en
# 213182         2014-07-04   FEMALE   105         basic            0       en
# 213199         2014-07-07     MALE   105         basic            0       en
# 213217                NaN   FEMALE    95      facebook            0       fr
# 213345         2014-07-01   FEMALE   105         basic            0       en
#
#        affiliate_channel affiliate_provider first_affiliate_tracked  \
# 388                other         craigslist               untracked
# 398                other         craigslist                  linked
# 627                other         craigslist                     omg
# 645               direct             direct               untracked
# 673                other         craigslist               untracked
# 777              content             google                  linked
# 1040               other         craigslist               untracked
# 1177              direct             direct               untracked
# 1190               other         craigslist               untracked
# 1200              direct             direct               untracked
# 1208              direct             direct               untracked
# 1239              direct             direct               untracked
# 1257              direct             direct               untracked
# 1308               other         craigslist                  linked
# 1314              direct             direct               untracked
# 1474               other         craigslist               untracked
# 1502       sem-non-brand             google               untracked
# 1529               other         craigslist                  linked
# 1615              direct             direct               untracked
# 1619                 seo             google               untracked
# 1739       sem-non-brand             google           tracked-other
# 1826              direct             direct               untracked
# 1860                 seo             google                  linked
# 1879              direct             direct               untracked
# 1889       sem-non-brand             google               untracked
# 2228               other         craigslist                     NaN
# 2235             content             google                     omg
# 2289              direct             direct               untracked
# 2497              direct             direct               untracked
# 2582       sem-non-brand             google                  linked
# ...                  ...                ...                     ...
# 209228            direct             direct                  linked
# 209672            direct             direct                  linked
# 210086            direct             direct               untracked
# 210232         sem-brand             google                     omg
# 210257            direct             direct               untracked
# 210335            direct             direct               untracked
# 210350            direct             direct               untracked
# 210793     sem-non-brand             google                     omg
# 210928            direct             direct                  linked
# 211074     sem-non-brand             google                     omg
# 211196            direct             direct                  linked
# 211228            direct             direct               untracked
# 211373            direct             direct               untracked
# 211388         sem-brand             google                     omg
# 211424            direct             direct                  linked
# 211496            direct             direct               untracked
# 211552         sem-brand             google                     omg
# 211728            direct             direct                  linked
# 212292            direct             direct                  linked
# 212372            direct             direct               untracked
# 212419         sem-brand             google                     omg
# 212720            direct             direct                     omg
# 212786            direct             direct               untracked
# 212862         sem-brand             google               untracked
# 212981         sem-brand             google                     omg
# 213106            direct             direct               untracked
# 213182            direct             direct                  linked
# 213199            direct             direct               untracked
# 213217               seo           facebook                  linked
# 213345            direct             direct                     omg
#
#        signup_app first_device_type   first_browser country_destination
# 388           Web   Windows Desktop         Firefox                  FR
# 398           Web            iPhone   Mobile Safari                  FR
# 627           Web       Mac Desktop          Safari                  FR
# 645           Web       Mac Desktop         Firefox                 NDF
# 673           Web       Mac Desktop          Safari                 NDF
# 777           Web       Mac Desktop          Safari                 NDF
# 1040          Web       Mac Desktop          Chrome                  US
# 1177          Web       Mac Desktop          Chrome                  US
# 1190          Web       Mac Desktop         Firefox                  US
# 1200          Web   Windows Desktop              IE                  US
# 1208          Web       Mac Desktop         Firefox                  US
# 1239          Web       Mac Desktop         Firefox                  CA
# 1257          Web   Windows Desktop          Chrome                  US
# 1308          Web   Windows Desktop          Chrome                 NDF
# 1314          Web     Other/Unknown       -unknown-                 NDF
# 1474          Web       Mac Desktop          Safari                 NDF
# 1502          Web   Windows Desktop          Chrome                  US
# 1529          Web   Windows Desktop              IE                 NDF
# 1615          Web   Windows Desktop              IE                  US
# 1619          Web       Mac Desktop          Safari                  US
# 1739          Web     Other/Unknown  Mobile Firefox                  US
# 1826          Web       Mac Desktop         Firefox               other
# 1860          Web   Windows Desktop              IE                  US
# 1879          Web   Windows Desktop         Firefox                  US
# 1889          Web              iPad   Mobile Safari                  US
# 2228          Web     Other/Unknown       -unknown-                 NDF
# 2235          Web       Mac Desktop          Safari                 NDF
# 2289          Web   Windows Desktop          Chrome                  US
# 2497          Web       Mac Desktop          Chrome               other
# 2582          Web              iPad   Mobile Safari                  FR
# ...           ...               ...             ...                 ...
# 209228        Web       Mac Desktop          Chrome                 NDF
# 209672      Moweb            iPhone   Mobile Safari                 NDF
# 210086        Web   Windows Desktop         Firefox                  US
# 210232        Web       Mac Desktop          Safari                  FR
# 210257        Web       Mac Desktop          Safari                  US
# 210335        iOS            iPhone       -unknown-                  US
# 210350        iOS            iPhone       -unknown-                 NDF
# 210793        Web   Windows Desktop              IE                 NDF
# 210928        Web       Mac Desktop          Safari                  GB
# 211074        Web   Windows Desktop              IE                 NDF
# 211196      Moweb            iPhone   Mobile Safari                  US
# 211228        iOS            iPhone       -unknown-                  US
# 211373        Web       Mac Desktop          Safari                 NDF
# 211388        Web       Mac Desktop         Firefox                  US
# 211424        Web              iPad   Mobile Safari                  US
# 211496        Web   Windows Desktop         Firefox                  US
# 211552        Web   Windows Desktop          Chrome                 NDF
# 211728        Web       Mac Desktop          Chrome                  US
# 212292      Moweb     Android Phone   Chrome Mobile                 NDF
# 212372        Web   Windows Desktop              IE                 NDF
# 212419        Web   Windows Desktop         Firefox                  US
# 212720        Web       Mac Desktop          Safari                  US
# 212786        Web   Windows Desktop              IE                 NDF
# 212862        Web              iPad   Mobile Safari                 NDF
# 212981        Web       Mac Desktop          Chrome                  US
# 213106        iOS            iPhone       -unknown-                 NDF
# 213182        Web            iPhone   Mobile Safari                  ES
# 213199        Web   Windows Desktop          Chrome                  US
# 213217      Moweb            iPhone   Mobile Safari                 NDF
# 213345        Web            iPhone   Mobile Safari                  US
#
# [2771 rows x 16 columns]

# %%
age_mean = int(train_users_pd['age'].mean())

# %%
train_users_pd.loc[train_users_pd['age'] > 80, 'age'] = age_mean

# %%
train_users_pd.loc[train_users_pd['age'] > 80, 'age']
# Out:
# Series([], Name: age, dtype: float64)

# %%
train_users_pd['age']
# Out:
# 0        NaN
# 1         38
# 2         56
# 3         42
# 4         41
# 5        NaN
# 6         46
# 7         47
# 8         50
# 9         46
# 10        36
# 11        47
# 12       NaN
# 13        37
# 14        36
# 15        33
# 16       NaN
# 17        31
# 18       NaN
# 19        29
# 20       NaN
# 21        30
# 22        40
# 23       NaN
# 24        40
# 25        26
# 26       NaN
# 27        32
# 28        35
# 29        37
#           ..
# 213436   NaN
# 213437   NaN
# 213438   NaN
# 213439    43
# 213440    24
# 213441    34
# 213442   NaN
# 213443    36
# 213444   NaN
# 213445    23
# 213446    32
# 213447   NaN
# 213448    32
# 213449   NaN
# 213450   NaN
# 213451   NaN
# 213452    33
# 213453    53
# 213454    31
# 213455    19
# 213456    37
# 213457    42
# 213458    73
# 213459    30
# 213460    25
# 213461    44
# 213462    21
# 213463   NaN
# 213464    31
# 213465    40
# Name: age, dtype: float64

# %%
train_users_pd['age'] = train_users_pd['age'].fillna(age_mean)

# %%
train_users_pd.loc[train_users_pd['age'] < 10, 'age'].size
# Out:
# 57

# %%
train_users_pd.loc[train_users_pd['age'] < 10, 'age'] = age_mean

# %% [markdown]
# ### logstic regression 을 적용하기 위해서 categorical data를 integer로 바꾸

# %%
train_users_pd['country_destination'].unique()
# Out:
# array(['NDF', 'US', 'other', 'FR', 'CA', 'GB', 'ES', 'IT', 'PT', 'NL',
#        'DE', 'AU'], dtype=object)

# %%
train_users_pd['gender'] = train_users_pd['gender'].astype('category')
train_users_pd['language'] = train_users_pd['language'].astype('category')
train_users_pd['country_destination'] = train_users_pd['country_destination'].astype('category')

# %%
train_users_pd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 213466 entries, 0 to 213465
# Data columns (total 16 columns):
# id                         213466 non-null object
# date_account_created       213466 non-null object
# timestamp_first_active     213466 non-null int64
# date_first_booking         88908 non-null object
# gender                     213466 non-null category
# age                        213466 non-null float64
# signup_method              213466 non-null object
# signup_flow                213466 non-null int64
# language                   213466 non-null category
# affiliate_channel          213466 non-null object
# affiliate_provider         213466 non-null object
# first_affiliate_tracked    207401 non-null object
# signup_app                 213466 non-null object
# first_device_type          213466 non-null object
# first_browser              213466 non-null object
# country_destination        213466 non-null category
# dtypes: category(3), float64(1), int64(2), object(10)
# memory usage: 23.4+ MB

# %%
cat_columns = train_users_pd.select_dtypes(['category']).columns
cat_columns
# Out:
# Index(['gender', 'language', 'country_destination'], dtype='object')

# %%
train_users_pd[cat_columns] = train_users_pd[cat_columns].apply(lambda x: x.cat.codes)

# %%
train_users_pd[['age','gender','country_destination']]
# Out:
#         age  gender  country_destination
# 0        49       2                    7
# 1        38       1                    7
# 2        56       0                   10
# 3        42       0                   11
# 4        41       2                   10
# 5        49       2                   10
# 6        46       0                   10
# 7        47       0                   10
# 8        50       0                   10
# 9        46       2                   10
# 10       36       0                   10
# 11       47       0                    7
# 12       49       2                    4
# 13       37       0                    7
# 14       36       0                    7
# 15       33       0                    1
# 16       49       2                    7
# 17       31       2                   10
# 18       49       2                    7
# 19       29       0                    4
# 20       49       2                   10
# 21       30       1                   10
# 22       40       2                   10
# 23       49       2                    7
# 24       40       0                    7
# 25       26       0                    4
# 26       49       2                    7
# 27       32       0                   10
# 28       35       2                    4
# 29       37       2                   10
# ...     ...     ...                  ...
# 213436   49       2                    7
# 213437   49       2                    7
# 213438   49       2                    7
# 213439   43       1                   10
# 213440   24       0                    7
# 213441   34       0                    3
# 213442   49       2                    7
# 213443   36       0                   10
# 213444   49       2                    7
# 213445   23       0                   10
# 213446   32       1                    7
# 213447   49       2                    7
# 213448   32       2                    7
# 213449   49       2                    7
# 213450   49       2                    7
# 213451   49       2                   10
# 213452   33       0                   10
# 213453   53       0                    6
# 213454   31       1                    7
# 213455   19       0                   11
# 213456   37       0                    7
# 213457   42       0                    7
# 213458   73       0                    7
# 213459   30       2                   10
# 213460   25       1                    9
# 213461   44       1                   10
# 213462   21       0                    7
# 213463   49       2                    5
# 213464   31       2                    8
# 213465   40       0                    7
#
# [213466 rows x 3 columns]
